# %% [markdown]
# ### Context
#
# #### Experiment Tools
# - WanDB

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in c:\users\cv002\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: PyYAML in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (5.3.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (2.8.1)
# Requirement already satisfied: promise<3,>=2.0 in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (2.3)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (5.7.2)
# Requirement already satisfied: GitPython>=1.0.0 in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (3.1.18)
# Requirement already satisfied: subprocess32>=3.5.3 in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (3.5.4)
# Requirement already satisfied: configparser>=3.8.1 in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (5.0.2)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (3.17.3)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (1.26.6)
# Requirement already satisfied: sentry-sdk>=1.0.0 in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (1.3.1)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (7.1.2)
# Requirement already satisfied: shortuuid>=0.5.0 in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (1.0.1)
# Requirement already satisfied: pathtools in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (0.1.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (0.4.0)
# Requirement already satisfied: six>=1.13.0 in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (1.15.0)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\cv002\anaconda3\lib\site-packages (from wandb) (2.24.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\cv002\anaconda3\lib\site-packages (from GitPython>=1.0.0->wandb) (4.0.7)
# Requirement already satisfied: certifi in c:\users\cv002\anaconda3\lib\site-packages (from sentry-sdk>=1.0.0->wandb) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\cv002\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\cv002\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\cv002\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (4.0.0)

# %%
sweep_config = {
  "name" : "mdc_sweep",
  "method" : "bayes",
  "parameters" : {
    "max_depth" : {
      "distribution": "int_uniform",
      "min":2,
      "max":15
    },
    "subsample" :{
      "distribution": "uniform",
      "min": 0.5,
      "max": 1.0
    },
    "colsample_bytree":{
      "distribution": "uniform",
      "min": 0.5,
      "max": 1.0
    }
  },
  "metric":{
      "name": "cv_loss",
      "goal": "minimize"
  }
}

# %%
import os
from os.path import join

import multiprocessing
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

import wandb

# 웹 서버 연결
wandb.init()

# optnua랑 비슷
sweep_id = wandb.sweep(sweep_config, 
                       project="medici wandb test")

n_cpus = multiprocessing.cpu_count()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter: ········
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\cv002/.netrc
#                 Tracking run with wandb version 0.11.2<br/>
#                 Syncing run <strong style="color:#cdcd00">frosty-feather-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jeongho/uncategorized" target="_blank">https://wandb.ai/jeongho/uncategorized</a><br/>
#                 Run page: <a href="https://wandb.ai/jeongho/uncategorized/runs/3rdy2inx" target="_blank">https://wandb.ai/jeongho/uncategorized/runs/3rdy2inx</a><br/>
#                 Run data is saved locally in <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_161321-3rdy2inx</code><br/><br/>
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# Create sweep with ID: 3x3z8ebw
# Sweep URL: https://wandb.ai/jeongho/medici%20wandb%20test/sweeps/3x3z8ebw

# %%
BASE_DIR = './data' 

train_path = os.path.join(BASE_DIR, 'train.csv')
test_path = os.path.join(BASE_DIR, 'test.csv')
submission_path = os.path.join(BASE_DIR, 'sample_submission.csv')

data = pd.read_csv(train_path)
test = pd.read_csv(test_path)

label = data['credit']

# %%
# 불필요한 컬럼 제거
data.drop(columns=['index', 'credit'], inplace=True)
test.drop(columns=['index'],         inplace=True)

# %%
cat_columns = [c for c, t in zip(data.dtypes.index, data.dtypes) if t == 'O'] 
num_columns = [c for c    in data.columns if c not in cat_columns]

print('Categorical Columns: \n{}\n'.format(cat_columns))
print('Numeric Columns: \n{}'.format(num_columns))
# Out:
# Categorical Columns:
# ['gender', 'car', 'reality', 'income_type', 'edu_type', 'family_type', 'house_type', 'occyp_type']
#
# Numeric Columns:
# ['child_num', 'income_total', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'FLAG_MOBIL', 'work_phone', 'phone', 'email', 'family_size', 'begin_month']

# %% [markdown]
# #### 라벨 데이터 인코딩

# %%
label = label.astype(int)

# %% [markdown]
# #### 전처리 프로세스 함수로 작성

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

def preprocess(x_train, x_valid, x_test):
    tmp_x_train = x_train.copy()
    tmp_x_valid = x_valid.copy()
    tmp_x_test  = x_test.copy()
    
    tmp_x_train.reset_index(drop=True, inplace=True)
    tmp_x_valid.reset_index(drop=True, inplace=True)
    
    # 결측치 처리
    imputer = SimpleImputer(strategy='most_frequent')
    tmp_x_train[cat_columns] = imputer.fit_transform(tmp_x_train[cat_columns])
    tmp_x_valid[cat_columns] = imputer.transform(tmp_x_valid[cat_columns])
    tmp_x_test[cat_columns]  = imputer.transform(tmp_x_test[cat_columns])
    
    # 스케일링
    scaler = StandardScaler()
    tmp_x_train[num_columns] = scaler.fit_transform(tmp_x_train[num_columns])
    tmp_x_valid[num_columns] = scaler.transform(tmp_x_valid[num_columns])
    tmp_x_test[num_columns]  = scaler.transform(tmp_x_test[num_columns])

    # 인코딩
    ohe = OneHotEncoder(sparse=False)
    ohe.fit(tmp_x_train[cat_columns])
    
    tmp_x_train_cat = pd.DataFrame(ohe.transform(tmp_x_train[cat_columns]))
    tmp_x_valid_cat = pd.DataFrame(ohe.transform(tmp_x_valid[cat_columns]))
    tmp_x_test_cat  = pd.DataFrame(ohe.transform(tmp_x_test[cat_columns]))
    
    tmp_x_train.drop(columns=cat_columns, inplace=True)
    tmp_x_valid.drop(columns=cat_columns, inplace=True)
    tmp_x_test.drop(columns=cat_columns, inplace=True)
    
    tmp_x_train = pd.concat([tmp_x_train, tmp_x_train_cat], axis=1)
    tmp_x_valid = pd.concat([tmp_x_valid, tmp_x_valid_cat], axis=1)
    tmp_x_test  = pd.concat([tmp_x_test, tmp_x_test_cat], axis=1)
    
    return tmp_x_train, tmp_x_valid, tmp_x_test

# %% [markdown]
# ### Ensemble

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
from xgboost import XGBClassifier

def train():
    with wandb.init() as run:
        params = wandb.config
        
        val_scores = list()
        n_splits = 5

        skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

        for i, (trn_idx, val_idx) in enumerate(skf.split(data, label)):
            x_train, y_train = data.iloc[trn_idx, :], label.iloc[trn_idx,]
            x_valid, y_valid = data.iloc[val_idx, :], label.iloc[val_idx,]

            # 전처리
            x_train, x_valid, x_test = preprocess(x_train, x_valid, test)

            # 모델 정의
            model = XGBClassifier(n_estimators=1000,
                                  max_depth=params['max_depth'],
                                  subsample=params['subsample'],
                                  colsample_bytree=params['colsample_bytree'],
#                                   tree_method='gpu_hist',
                                  n_jobs=n_cpus-1)

            # 모델 학습
            model.fit(x_train, y_train, 
                      eval_metric='mlogloss', 
                      eval_set=[[x_train, y_train], [x_valid, y_valid]],
                      early_stopping_rounds=100,
                      verbose=100) # 

            # 훈련, 검증 데이터 log_loss 확인
            trn_logloss = log_loss(y_train, model.predict_proba(x_train))
            val_logloss = log_loss(y_valid, model.predict_proba(x_valid))
            print('{} Fold, train logloss : {:.4f}4, validation logloss : {:.4f}'.format(i, trn_logloss, val_logloss))

            val_scores.append(val_logloss)
            
        metrics = {"cv_loss": np.mean(val_scores)}
        wandb.log(metrics)
count = 5
wandb.agent(sweep_id, function=train, count=count)
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: Agent Starting Run: ybhpchnr with config:
# wandb: 	colsample_bytree: 0.8356307450676174
# wandb: 	max_depth: 15
# wandb: 	subsample: 0.5760809165624917
#                 Tracking run with wandb version 0.11.2<br/>
#                 Syncing run <strong style="color:#cdcd00">northern-sweep-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/sweeps/3x3z8ebw" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/sweeps/3x3z8ebw</a><br/>
# Run page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/runs/ybhpchnr" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/runs/ybhpchnr</a><br/>
#                 Run data is saved locally in <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_162121-ybhpchnr</code><br/><br/>
# [0]	validation_0-mlogloss:0.94563	validation_1-mlogloss:0.97137
# [100]	validation_0-mlogloss:0.10372	validation_1-mlogloss:0.90358
# [117]	validation_0-mlogloss:0.09063	validation_1-mlogloss:0.93819
# 0 Fold, train logloss : 0.43064, validation logloss : 0.7266
# [0]	validation_0-mlogloss:0.94650	validation_1-mlogloss:0.97288
# [100]	validation_0-mlogloss:0.10204	validation_1-mlogloss:0.93990
# [116]	validation_0-mlogloss:0.09007	validation_1-mlogloss:0.97461
# 1 Fold, train logloss : 0.42554, validation logloss : 0.7400
# [0]	validation_0-mlogloss:0.96810	validation_1-mlogloss:0.99226
# [100]	validation_0-mlogloss:0.10292	validation_1-mlogloss:0.93722
# [119]	validation_0-mlogloss:0.08780	validation_1-mlogloss:0.98058
# 2 Fold, train logloss : 0.40664, validation logloss : 0.7343
# [0]	validation_0-mlogloss:0.96698	validation_1-mlogloss:0.99152
# [100]	validation_0-mlogloss:0.10260	validation_1-mlogloss:0.92812
# [118]	validation_0-mlogloss:0.08848	validation_1-mlogloss:0.96647
# 3 Fold, train logloss : 0.42504, validation logloss : 0.7321
# [0]	validation_0-mlogloss:0.97096	validation_1-mlogloss:0.99253
# [100]	validation_0-mlogloss:0.10121	validation_1-mlogloss:0.94359
# [117]	validation_0-mlogloss:0.08730	validation_1-mlogloss:0.98439
# 4 Fold, train logloss : 0.41564, validation logloss : 0.7277
# <br/>Waiting for W&B process to finish, PID 9444<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_162121-ybhpchnr\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_162121-ybhpchnr\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>cv_loss</td><td>0.73213</td></tr><tr><td>_runtime</td><td>123</td></tr><tr><td>_timestamp</td><td>1628321004</td></tr><tr><td>_step</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>cv_loss</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">northern-sweep-1</strong>: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/runs/ybhpchnr" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/runs/ybhpchnr</a><br/>
# wandb: Agent Starting Run: 45vpx00d with config:
# wandb: 	colsample_bytree: 0.7496732139764124
# wandb: 	max_depth: 5
# wandb: 	subsample: 0.9307190923092045
# wandb: Currently logged in as: jeongho (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.11.2<br/>
#                 Syncing run <strong style="color:#cdcd00">gentle-sweep-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/sweeps/3x3z8ebw" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/sweeps/3x3z8ebw</a><br/>
# Run page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/runs/45vpx00d" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/runs/45vpx00d</a><br/>
#                 Run data is saved locally in <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_162333-45vpx00d</code><br/><br/>
# [0]	validation_0-mlogloss:0.97674	validation_1-mlogloss:0.97753
# [100]	validation_0-mlogloss:0.62547	validation_1-mlogloss:0.74374
# [200]	validation_0-mlogloss:0.53258	validation_1-mlogloss:0.72747
# [300]	validation_0-mlogloss:0.46227	validation_1-mlogloss:0.72181
# [400]	validation_0-mlogloss:0.41016	validation_1-mlogloss:0.72350
# [408]	validation_0-mlogloss:0.40650	validation_1-mlogloss:0.72441
# 0 Fold, train logloss : 0.45744, validation logloss : 0.7204
# [0]	validation_0-mlogloss:0.97513	validation_1-mlogloss:0.97931
# [100]	validation_0-mlogloss:0.62132	validation_1-mlogloss:0.75743
# [200]	validation_0-mlogloss:0.52607	validation_1-mlogloss:0.74419
# [300]	validation_0-mlogloss:0.45804	validation_1-mlogloss:0.73991
# [380]	validation_0-mlogloss:0.41667	validation_1-mlogloss:0.74125
# 1 Fold, train logloss : 0.46854, validation logloss : 0.7387
# [0]	validation_0-mlogloss:1.00449	validation_1-mlogloss:1.00714
# [100]	validation_0-mlogloss:0.62594	validation_1-mlogloss:0.75418
# [200]	validation_0-mlogloss:0.52990	validation_1-mlogloss:0.73718
# [300]	validation_0-mlogloss:0.46298	validation_1-mlogloss:0.73650
# [351]	validation_0-mlogloss:0.43472	validation_1-mlogloss:0.73804
# 2 Fold, train logloss : 0.49284, validation logloss : 0.7350
# [0]	validation_0-mlogloss:1.00428	validation_1-mlogloss:1.00645
# [100]	validation_0-mlogloss:0.62625	validation_1-mlogloss:0.74708
# [200]	validation_0-mlogloss:0.53198	validation_1-mlogloss:0.72898
# [300]	validation_0-mlogloss:0.46502	validation_1-mlogloss:0.72513
# [376]	validation_0-mlogloss:0.42318	validation_1-mlogloss:0.72521
# 3 Fold, train logloss : 0.47884, validation logloss : 0.7246
# [0]	validation_0-mlogloss:1.00442	validation_1-mlogloss:1.00690
# [100]	validation_0-mlogloss:0.63201	validation_1-mlogloss:0.74849
# [200]	validation_0-mlogloss:0.53194	validation_1-mlogloss:0.73303
# [300]	validation_0-mlogloss:0.46268	validation_1-mlogloss:0.73057
# [360]	validation_0-mlogloss:0.43023	validation_1-mlogloss:0.73388
# 4 Fold, train logloss : 0.48684, validation logloss : 0.7285
# <br/>Waiting for W&B process to finish, PID 18496<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_162333-45vpx00d\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_162333-45vpx00d\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>cv_loss</td><td>0.72945</td></tr><tr><td>_runtime</td><td>137</td></tr><tr><td>_timestamp</td><td>1628321150</td></tr><tr><td>_step</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>cv_loss</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">gentle-sweep-2</strong>: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/runs/45vpx00d" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/runs/45vpx00d</a><br/>
# wandb: Agent Starting Run: sngs674y with config:
# wandb: 	colsample_bytree: 0.6852873622490906
# wandb: 	max_depth: 5
# wandb: 	subsample: 0.8267006346573685
#                 Tracking run with wandb version 0.11.2<br/>
#                 Syncing run <strong style="color:#cdcd00">neat-sweep-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/sweeps/3x3z8ebw" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/sweeps/3x3z8ebw</a><br/>
# Run page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/runs/sngs674y" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/runs/sngs674y</a><br/>
#                 Run data is saved locally in <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_162559-sngs674y</code><br/><br/>
# [0]	validation_0-mlogloss:0.97657	validation_1-mlogloss:0.97733
# [100]	validation_0-mlogloss:0.62933	validation_1-mlogloss:0.74799
# [200]	validation_0-mlogloss:0.53065	validation_1-mlogloss:0.72892
# [300]	validation_0-mlogloss:0.46152	validation_1-mlogloss:0.72699
# [400]	validation_0-mlogloss:0.41044	validation_1-mlogloss:0.73147
# [402]	validation_0-mlogloss:0.40960	validation_1-mlogloss:0.73162
# 0 Fold, train logloss : 0.45954, validation logloss : 0.7268
# [0]	validation_0-mlogloss:0.97588	validation_1-mlogloss:0.97986
# [100]	validation_0-mlogloss:0.62489	validation_1-mlogloss:0.75904
# [200]	validation_0-mlogloss:0.52915	validation_1-mlogloss:0.74420
# [300]	validation_0-mlogloss:0.45968	validation_1-mlogloss:0.74337
# [400]	validation_0-mlogloss:0.40716	validation_1-mlogloss:0.74683
# [407]	validation_0-mlogloss:0.40390	validation_1-mlogloss:0.74677
# 1 Fold, train logloss : 0.45614, validation logloss : 0.7426
# [0]	validation_0-mlogloss:1.00540	validation_1-mlogloss:1.00790
# [100]	validation_0-mlogloss:0.62731	validation_1-mlogloss:0.75309
# [200]	validation_0-mlogloss:0.52997	validation_1-mlogloss:0.73890
# [300]	validation_0-mlogloss:0.46321	validation_1-mlogloss:0.73615
# [400]	validation_0-mlogloss:0.40907	validation_1-mlogloss:0.73784
# [443]	validation_0-mlogloss:0.38912	validation_1-mlogloss:0.74178
# 2 Fold, train logloss : 0.43754, validation logloss : 0.7345
# [0]	validation_0-mlogloss:1.00494	validation_1-mlogloss:1.00650
# [100]	validation_0-mlogloss:0.62569	validation_1-mlogloss:0.74826
# [200]	validation_0-mlogloss:0.52920	validation_1-mlogloss:0.73321
# [300]	validation_0-mlogloss:0.46094	validation_1-mlogloss:0.73083
# [386]	validation_0-mlogloss:0.41476	validation_1-mlogloss:0.73513
# 3 Fold, train logloss : 0.46834, validation logloss : 0.7297
# [0]	validation_0-mlogloss:1.00507	validation_1-mlogloss:1.00673
# [100]	validation_0-mlogloss:0.62413	validation_1-mlogloss:0.75125
# [200]	validation_0-mlogloss:0.52314	validation_1-mlogloss:0.73743
# [300]	validation_0-mlogloss:0.45713	validation_1-mlogloss:0.73842
# [307]	validation_0-mlogloss:0.45309	validation_1-mlogloss:0.73912
# 4 Fold, train logloss : 0.51704, validation logloss : 0.7369
# <br/>Waiting for W&B process to finish, PID 17760<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_162559-sngs674y\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_162559-sngs674y\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>cv_loss</td><td>0.73407</td></tr><tr><td>_runtime</td><td>136</td></tr><tr><td>_timestamp</td><td>1628321296</td></tr><tr><td>_step</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>cv_loss</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">neat-sweep-3</strong>: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/runs/sngs674y" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/runs/sngs674y</a><br/>
# wandb: Agent Starting Run: 0sw2q1k4 with config:
# wandb: 	colsample_bytree: 0.8145134280029038
# wandb: 	max_depth: 2
# wandb: 	subsample: 0.5524820822631327
#                 Tracking run with wandb version 0.11.2<br/>
#                 Syncing run <strong style="color:#cdcd00">radiant-sweep-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/sweeps/3x3z8ebw" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/sweeps/3x3z8ebw</a><br/>
# Run page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/runs/0sw2q1k4" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/runs/0sw2q1k4</a><br/>
#                 Run data is saved locally in <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_162825-0sw2q1k4</code><br/><br/>
# [0]	validation_0-mlogloss:0.97974	validation_1-mlogloss:0.97843
# [100]	validation_0-mlogloss:0.77394	validation_1-mlogloss:0.79296
# [200]	validation_0-mlogloss:0.75338	validation_1-mlogloss:0.78651
# [300]	validation_0-mlogloss:0.73587	validation_1-mlogloss:0.78100
# [400]	validation_0-mlogloss:0.72017	validation_1-mlogloss:0.77706
# [500]	validation_0-mlogloss:0.70757	validation_1-mlogloss:0.77160
# [600]	validation_0-mlogloss:0.69580	validation_1-mlogloss:0.77036
# [700]	validation_0-mlogloss:0.68532	validation_1-mlogloss:0.76794
# [800]	validation_0-mlogloss:0.67634	validation_1-mlogloss:0.76784
# [900]	validation_0-mlogloss:0.66735	validation_1-mlogloss:0.76681
# [999]	validation_0-mlogloss:0.65898	validation_1-mlogloss:0.76450
# 0 Fold, train logloss : 0.65994, validation logloss : 0.7645
# [0]	validation_0-mlogloss:0.97879	validation_1-mlogloss:0.98076
# [100]	validation_0-mlogloss:0.77000	validation_1-mlogloss:0.80035
# [200]	validation_0-mlogloss:0.74623	validation_1-mlogloss:0.79386
# [300]	validation_0-mlogloss:0.72911	validation_1-mlogloss:0.79130
# [400]	validation_0-mlogloss:0.71365	validation_1-mlogloss:0.78879
# [500]	validation_0-mlogloss:0.69984	validation_1-mlogloss:0.78699
# [600]	validation_0-mlogloss:0.68805	validation_1-mlogloss:0.78474
# [700]	validation_0-mlogloss:0.67797	validation_1-mlogloss:0.78223
# [800]	validation_0-mlogloss:0.66892	validation_1-mlogloss:0.78153
# [821]	validation_0-mlogloss:0.66720	validation_1-mlogloss:0.78151
# 1 Fold, train logloss : 0.67594, validation logloss : 0.7810
# [0]	validation_0-mlogloss:1.00839	validation_1-mlogloss:1.00881
# [100]	validation_0-mlogloss:0.77302	validation_1-mlogloss:0.79366
# [200]	validation_0-mlogloss:0.75100	validation_1-mlogloss:0.78575
# [300]	validation_0-mlogloss:0.73350	validation_1-mlogloss:0.78228
# [400]	validation_0-mlogloss:0.71710	validation_1-mlogloss:0.78007
# [500]	validation_0-mlogloss:0.70347	validation_1-mlogloss:0.77591
# [600]	validation_0-mlogloss:0.69228	validation_1-mlogloss:0.77494
# [700]	validation_0-mlogloss:0.68208	validation_1-mlogloss:0.77272
# [800]	validation_0-mlogloss:0.67257	validation_1-mlogloss:0.77327
# [811]	validation_0-mlogloss:0.67142	validation_1-mlogloss:0.77330
# 2 Fold, train logloss : 0.68074, validation logloss : 0.7724
# [0]	validation_0-mlogloss:1.00822	validation_1-mlogloss:1.00855
# [100]	validation_0-mlogloss:0.77224	validation_1-mlogloss:0.79572
# [200]	validation_0-mlogloss:0.75041	validation_1-mlogloss:0.78615
# [300]	validation_0-mlogloss:0.73326	validation_1-mlogloss:0.77971
# [400]	validation_0-mlogloss:0.71783	validation_1-mlogloss:0.77510
# [500]	validation_0-mlogloss:0.70423	validation_1-mlogloss:0.77190
# [600]	validation_0-mlogloss:0.69273	validation_1-mlogloss:0.76998
# [700]	validation_0-mlogloss:0.68262	validation_1-mlogloss:0.76944
# [800]	validation_0-mlogloss:0.67323	validation_1-mlogloss:0.76928
# [900]	validation_0-mlogloss:0.66476	validation_1-mlogloss:0.76811
# [999]	validation_0-mlogloss:0.65675	validation_1-mlogloss:0.76680
# 3 Fold, train logloss : 0.66154, validation logloss : 0.7667
# [0]	validation_0-mlogloss:1.00845	validation_1-mlogloss:1.00886
# [100]	validation_0-mlogloss:0.77425	validation_1-mlogloss:0.79267
# [200]	validation_0-mlogloss:0.75104	validation_1-mlogloss:0.78490
# [300]	validation_0-mlogloss:0.73315	validation_1-mlogloss:0.77997
# [400]	validation_0-mlogloss:0.71765	validation_1-mlogloss:0.77545
# [500]	validation_0-mlogloss:0.70392	validation_1-mlogloss:0.77193
# [600]	validation_0-mlogloss:0.69257	validation_1-mlogloss:0.77040
# [700]	validation_0-mlogloss:0.68235	validation_1-mlogloss:0.76857
# [800]	validation_0-mlogloss:0.67276	validation_1-mlogloss:0.76710
# [900]	validation_0-mlogloss:0.66387	validation_1-mlogloss:0.76821
# [910]	validation_0-mlogloss:0.66318	validation_1-mlogloss:0.76802
# 4 Fold, train logloss : 0.67174, validation logloss : 0.7667
# <br/>Waiting for W&B process to finish, PID 11240<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_162825-0sw2q1k4\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_162825-0sw2q1k4\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>cv_loss</td><td>0.77025</td></tr><tr><td>_runtime</td><td>114</td></tr><tr><td>_timestamp</td><td>1628321419</td></tr><tr><td>_step</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>cv_loss</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">radiant-sweep-4</strong>: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/runs/0sw2q1k4" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/runs/0sw2q1k4</a><br/>
# wandb: Agent Starting Run: 3q8jw5zz with config:
# wandb: 	colsample_bytree: 0.6748309527123748
# wandb: 	max_depth: 9
# wandb: 	subsample: 0.976503047280304
#                 Tracking run with wandb version 0.11.2<br/>
#                 Syncing run <strong style="color:#cdcd00">avid-sweep-5</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test</a><br/>
#                 Sweep page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/sweeps/3x3z8ebw" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/sweeps/3x3z8ebw</a><br/>
# Run page: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/runs/3q8jw5zz" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/runs/3q8jw5zz</a><br/>
#                 Run data is saved locally in <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_163027-3q8jw5zz</code><br/><br/>
# [0]	validation_0-mlogloss:0.96677	validation_1-mlogloss:0.97546
# [100]	validation_0-mlogloss:0.38103	validation_1-mlogloss:0.71453
# [177]	validation_0-mlogloss:0.26652	validation_1-mlogloss:0.74080
# 0 Fold, train logloss : 0.42654, validation logloss : 0.7123
# [0]	validation_0-mlogloss:0.96582	validation_1-mlogloss:0.97807
# [100]	validation_0-mlogloss:0.37537	validation_1-mlogloss:0.73701
# [164]	validation_0-mlogloss:0.27001	validation_1-mlogloss:0.76238
# 1 Fold, train logloss : 0.45754, validation logloss : 0.7340
# [0]	validation_0-mlogloss:0.99468	validation_1-mlogloss:1.00290
# [100]	validation_0-mlogloss:0.37558	validation_1-mlogloss:0.73315
# [174]	validation_0-mlogloss:0.26192	validation_1-mlogloss:0.76132
# 2 Fold, train logloss : 0.43024, validation logloss : 0.7290
# [0]	validation_0-mlogloss:0.99261	validation_1-mlogloss:1.00159
# [100]	validation_0-mlogloss:0.36678	validation_1-mlogloss:0.72960
# [181]	validation_0-mlogloss:0.25053	validation_1-mlogloss:0.76118
# 3 Fold, train logloss : 0.41134, validation logloss : 0.7261
# [0]	validation_0-mlogloss:0.99382	validation_1-mlogloss:1.00187
# [100]	validation_0-mlogloss:0.37806	validation_1-mlogloss:0.73118
# [181]	validation_0-mlogloss:0.25445	validation_1-mlogloss:0.76467
# 4 Fold, train logloss : 0.41944, validation logloss : 0.7274
# <br/>Waiting for W&B process to finish, PID 19696<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_163027-3q8jw5zz\logs\debug.log</code>
# Find internal logs for this run at: <code>C:\Users\cv002\Google Drive\__데이콘 캐글 프로젝트\wandb\run-20210807_163027-3q8jw5zz\logs\debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>cv_loss</td><td>0.72574</td></tr><tr><td>_runtime</td><td>108</td></tr><tr><td>_timestamp</td><td>1628321535</td></tr><tr><td>_step</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>cv_loss</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">avid-sweep-5</strong>: <a href="https://wandb.ai/jeongho/medici%20wandb%20test/runs/3q8jw5zz" target="_blank">https://wandb.ai/jeongho/medici%20wandb%20test/runs/3q8jw5zz</a><br/>

# %%
# submit.to_csv('oof_first_submit.csv', index=False)
